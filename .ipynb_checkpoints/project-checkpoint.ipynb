# %%
import pandas_datareader.data as web
import pandas as pd
import datetime as dt

# %% [markdown]
# ## Data
# ###### We are going to get Stock information for the following Indexes:
#
# * FTSE 100(UK)
# * S&P 500(USA)
# * Dow Jones Industrial Average(USA)
# * NASDAQ Composite(USA)
# * Hang Seng Index(CHINA)
# * Nikkei 225(JAPAN)
# * CAC 40(FRANCE)
# * IBEX 35 Index(SPAIN)
# * FTSE MIB Index(ITALY)
# * Austrian Traded Index in EUR(AUSTRIA)

# %%
df = web.DataReader('\^FTSE','yahoo')

# %%
df1 = web.DataReader('^GSPC','yahoo')

# %%
df2 = web.DataReader('^DJI','yahoo')

# %%
df3 = web.DataReader('^IXIC','yahoo')

# %%
df4 = web.DataReader('^HSI','yahoo')

# %%
df8 = web.DataReader('^N225','yahoo')

# %%
df5 = web.DataReader('^FCHI','yahoo')

# %%
df6 = web.DataReader('^IBEX','yahoo')

# %%
df7 = web.DataReader('\FTSEMIB.MI','yahoo')

# %%
df9 = web.DataReader('^ATX','yahoo')

# %%
start = dt.datetime(2009,11,1)

# %%
end = dt.datetime(2019,11,1)

# %%
df10 = web.DataReader(['\^FTSE','^GSPC','^DJI','^IXIC','^HSI','^N225','^FCHI','^IBEX','\FTSEMIB.MI','^ATX'],'yahoo',start,end)

# %%
df10.tail()
# Out:
# Attributes    Adj Close                                                        \
# Symbols          \^FTSE        ^GSPC          ^DJI        ^IXIC          ^HSI
# Date
# 2019-10-28  7331.299805  3039.419922  27090.720703  8325.990234  26891.259766
# 2019-10-29  7306.299805  3036.889893  27071.460938  8276.849609  26786.759766
# 2019-10-30  7330.799805  3046.770020  27186.689453  8303.980469  26667.710938
# 2019-10-31  7248.399902  3037.560059  27046.230469  8292.360352  26906.720703
# 2019-11-01  7302.399902  3066.909912  27347.359375  8386.400391  27100.759766
#
# Attributes                                                                   \
# Symbols            ^N225        ^FCHI        ^IBEX \FTSEMIB.MI         ^ATX
# Date
# 2019-10-28  22867.269531  5730.569824  9433.000000     22696.0  3189.370117
# 2019-10-29  22974.130859  5740.140137  9400.099609     22681.0  3190.520020
# 2019-10-30  22843.119141  5765.870117  9284.500000     22646.0  3171.209961
# ...

# %%
df10.head()
# Out:
# Attributes    Adj Close                                                        \
# Symbols          \^FTSE        ^GSPC          ^DJI        ^IXIC          ^HSI
# Date
# 2009-11-02  5104.500000  1042.880005   9789.440430  2049.199951  21620.189453
# 2009-11-03  5037.200195  1045.410034   9771.910156  2057.320068  21240.060547
# 2009-11-04  5107.899902  1046.500000   9802.139648  2055.520020  21614.769531
# 2009-11-05  5125.600098  1066.630005  10005.959961  2105.320068  21479.080078
# 2009-11-06  5142.700195  1069.300049  10023.419922  2112.439941  21829.720703
#
# Attributes                                                                   \
# Symbols           ^N225        ^FCHI         ^IBEX \FTSEMIB.MI         ^ATX
# Date
# 2009-11-02  9802.950195  3639.459961  11465.788086     22298.0  2525.840088
# 2009-11-03          NaN  3584.250000  11242.388672     21947.0  2460.100098
# 2009-11-04  9844.309570  3670.330078  11387.688477     22386.0  2526.879883
# ...

# %%
df10.describe()
# Out:
# Attributes    Adj Close                                                        \
# Symbols          \^FTSE        ^GSPC          ^DJI        ^IXIC          ^HSI
# count       2527.000000  2518.000000   2518.000000  2518.000000   2465.000000
# mean        6479.776808  1929.456175  17320.312924  4639.280898  23671.238719
# std          724.545418   579.365897   5054.960949  1838.906262   3175.614530
# min         4805.799805  1022.580017   9686.480469  2049.199951  16250.269531
# 25%         5868.800049  1360.664978  12837.330078  2927.862488  21424.789062
# 50%         6568.399902  1964.630005  16845.005859  4533.080078  23064.560547
# 75%         7093.850098  2388.540100  20951.127930  6074.642334  25701.630859
# max         7877.500000  3066.909912  27359.160156  8386.400391  33154.121094
#
# Attributes                                                         \
# Symbols            ^N225        ^FCHI         ^IBEX   \FTSEMIB.MI
# ...
